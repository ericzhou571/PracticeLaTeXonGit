# %%
from pyzbar import pyzbar
import cv2
import numpy as np

# %%
im=cv2.imread('IMG_6869.jpg')

# %%
img_yuv = cv2.cvtColor(im, cv2.COLOR_BGR2YUV)

# %%
import matplotlib.pyplot as plt
plt.imshow(img_yuv)
plt.show()

# %%
len(deocdeobject)
# Out:
# 0

# %%
 for obj in deocdeobject:
    print('Type : ', obj.type)
    print('Data : ', obj.data,'\n')
