# %%
from pyzbar import pyzbar
import cv2
import numpy as np

# %%
im=cv2.imread('IMG_6869.jpg')

# %%
deocdeobject=pyzbar.decode(im)

# %%
import matplotlib.pyplot as plt
plt.imshow(im,cmap='gray')
plt.show()

# %%
cv2.imshow("Results", im)
